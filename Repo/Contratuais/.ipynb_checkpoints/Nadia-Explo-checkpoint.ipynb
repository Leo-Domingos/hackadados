# %%
# The following two lines are only necessary to run once.
# Comment out otherwise for speed-up.
from google.cloud.bigquery import Client, QueryJobConfig
client = Client()

query = """SELECT 
ID, 
NmMotivoContratoFinanceiro,
Sub_Produto,
VrRenda,
VrContrato,
VrFinanciamento,
VrEntrada,
QtParcelas,
FL_EDUCACAO_F1,
FL_EDUCACAO_F2,
FL_EDUCACAO_F3,
FL_EDUCACAO_F4,
AaFabricacaoVeiculo,
CdMarca,
VrMercado,
FlZeroKm,
QtCilindradaVeiculo,
QtQuilometragemVeiculo,
CdOcupacaoCBO,
QtAnoIdade, 
fl_renovou,
duracao_segundos 
FROM `hacka-1.dataset.view_dados_hacka`
where FL_EDUCACAO_F2 is not null 
"""

job = client.query(query)
df = job.to_dataframe()

# %%
df.shape
# Out:
# (20823, 22)

# %%
df.head()
# Out:
#       ID NmMotivoContratoFinanceiro                          Sub_Produto  \
# 0  29174   FLUXO FINANCEIRO INICIAL              CDC VEICULOS DE PASSEIO
# 1  29375   FLUXO FINANCEIRO INICIAL              CDC VEICULOS DE PASSEIO
# 2  39749   FLUXO FINANCEIRO INICIAL              CDC VEICULOS DE PASSEIO
# 3  48016   FLUXO FINANCEIRO INICIAL  REFINANCIAMENTO VEICULOS DE PASSEIO
# 4  27486   FLUXO FINANCEIRO INICIAL              CDC VEICULOS DE PASSEIO
#
#     VrRenda  VrContrato  VrFinanciamento  VrEntrada  QtParcelas  FL_KIDS_F4  \
# 0 -1.116945    1.664057         1.568579  -1.980685          13         0.0
# 1  0.363946    0.017024        -0.064025   0.829642          48         0.0
# 2 -0.637906   -2.337455        -1.845968  -1.103448          60         0.0
# 3 -0.224577    0.275575         0.504604  -0.210256          60         0.0
# 4 -0.449425    1.156980         0.709244  -1.427411          54         0.0
#
#    AaFabricacaoVeiculo     CdMarca  VrMercado FlZeroKm  QtCilindradaVeiculo  \
# 0               2003.0       HONDA   0.613193        N           999.000000
# 1               2021.0  VOLKSWAGEN   1.083674        N          1598.000000
# 2               2021.0     CITROEN  -0.037656        N          1591.328264
# 3               2021.0  VOLKSWAGEN   0.417111        N          1598.000000
# 4                  NaN               1.089088        N          1800.000000
#
#    QtQuilometragemVeiculo  CdOcupacaoCBO  QtAnoIdade  fl_renovou  \
# 0                 87546.0  Indeterminado        19.0           0
# 1                 89976.0           2684         1.0           0
# 2                106916.0  Indeterminado         1.0           0
# 3                     NaN           2684         1.0           0
# 4                 73524.0  Indeterminado         NaN           0
#
#    duracao_segundos
# 0             615.0
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df.count()/len(df.index)
# Out:
# ID                            1.000000
# NmMotivoContratoFinanceiro    1.000000
# Sub_Produto                   1.000000
# VrRenda                       0.999188
# VrContrato                    1.000000
# VrFinanciamento               1.000000
# VrEntrada                     0.997449
# QtParcelas                    1.000000
# AaFabricacaoVeiculo           0.999652
# CdMarca                       1.000000
# VrMercado                     1.000000
# FlZeroKm                      1.000000
# QtCilindradaVeiculo           0.998144
# QtQuilometragemVeiculo        0.967761
# CdOcupacaoCBO                 1.000000
# QtAnoIdade                    0.999652
# fl_renovou                    1.000000
# duracao_segundos              0.499826
# dtype: float64

# %%
df_subprod = df.groupby(by=['FL_EDUCACAO_F2','fl_renovou']).ID.count().unstack().reset_index()
df_subprod['perc'] = df_subprod[1]/(df_subprod[0]+df_subprod[1])*100
df_subprod

#fl_renovou	FL_KIDS_F1	0	1	perc
#0	0.0	19646	745	3.653573
#1	1.0	585	39	6.250000 > OBS. A porcentagem de renovações é o dobro quando tem criança no nível 

#fl_renovou	FL_MATERIAL_DE_CONSTRUCAO_F1	0	1	perc
#0	0.0	19150	712	3.584735
#1	1.0	1113	74	6.234204
# Out:
# fl_renovou  FL_EDUCACAO_F2      0    1      perc
# 0                      0.0  19592  750  3.686953
# 1                      1.0    455   26  5.405405

# %%
df_subprod = df.groupby(by=['VrRenda','fl_renovou']).ID.count().unstack().reset_index()
df_subprod['perc'] = df_subprod[1]/(df_subprod[0]+df_subprod[1])*100
df_subprod
# Out:
# fl_renovou   VrRenda    0   1  perc
# 0          -5.238109  1.0 NaN   NaN
# 1          -3.489662  1.0 NaN   NaN
# 2          -3.320812  1.0 NaN   NaN
# 3          -3.242158  1.0 NaN   NaN
# 4          -3.118751  1.0 NaN   NaN
# ...              ...  ...  ..   ...
# 49947       3.693873  1.0 NaN   NaN
# 49948       4.792657  1.0 NaN   NaN
# 49949       4.898272  1.0 NaN   NaN
# 49950       5.156071  1.0 NaN   NaN
# 49951       5.173669  1.0 NaN   NaN
#
# [49952 rows x 4 columns]

# %%
df.groupby(by='QtParcelas').ID.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='QtParcelas'>

# %%
df_subprod = df.groupby(by=['AaFabricacaoVeiculo','fl_renovou']).ID.count().unstack().reset_index()
df_subprod['perc'] = df_subprod[1]/(df_subprod[0]+df_subprod[1])*100
df_subprod
# Out:
# fl_renovou  AaFabricacaoVeiculo       0      1      perc
# 0                        2003.0     7.0    NaN       NaN
# 1                        2004.0    72.0    NaN       NaN
# 2                        2005.0   421.0    5.0  1.173709
# 3                        2006.0   388.0   14.0  3.482587
# 4                        2007.0     1.0    NaN       NaN
# 5                        2008.0  3339.0   78.0  2.282704
# 6                        2009.0  3463.0  139.0  3.858967
# 7                        2010.0  6208.0  223.0  3.467579
# 8                        2011.0  5567.0  219.0  3.784998
# 9                        2012.0  5862.0  233.0  3.822806
# 10                       2013.0  5787.0  164.0  2.755839
# 11                       2014.0  6230.0  127.0  1.997798
# 12                       2015.0  1024.0   32.0  3.030303
# 13                       2016.0  2215.0   53.0  2.336861
# 14                       2017.0  4403.0  170.0  3.717472
# 15                       2018.0   718.0   22.0  2.972973
# 16                       2019.0  1366.0   59.0  4.140351
# 17                       2020.0   936.0   44.0  4.489796
# 18                       2021.0   118.0    1.0  0.840336
# 19                       2022.0   267.0    7.0  2.554745

# %%
df_subprod = df.groupby(by=['QtParcelas','fl_renovou']).ID.count().unstack().reset_index()
df_subprod['perc'] = df_subprod[1]/(df_subprod[0]+df_subprod[1])*100
df_subprod
# Out:
# fl_renovou  QtParcelas        0       1       perc
# 0                   11      2.0     NaN        NaN
# 1                   12      9.0     1.0  10.000000
# 2                   13    115.0     6.0   4.958678
# 3                   14    174.0     8.0   4.395604
# 4                   15      4.0     NaN        NaN
# 5                   16      4.0     NaN        NaN
# 6                   17      6.0     NaN        NaN
# 7                   18      1.0     NaN        NaN
# 8                   19      1.0     NaN        NaN
# 9                   20      2.0     NaN        NaN
# 10                  21      4.0     NaN        NaN
# 11                  22      2.0     NaN        NaN
# 12                  23      5.0     NaN        NaN
# 13                  24   1341.0    48.0   3.455724
# 14                  25     41.0     NaN        NaN
# 15                  26     30.0     5.0  14.285714
# 16                  27     36.0     3.0   7.692308
# 17                  28     16.0     NaN        NaN
# 18                  29      1.0     NaN        NaN
# 19                  30      2.0     NaN        NaN
# 20                  31      8.0     NaN        NaN
# 21                  32      9.0     NaN        NaN
# 22                  33      3.0     NaN        NaN
# 23                  34     33.0     1.0   2.941176
# 24                  35     23.0     NaN        NaN
# 25                  36   5239.0   131.0   2.439479
# 26                  37     64.0     2.0   3.030303
# 27                  38      5.0     NaN        NaN
# 28                  39     27.0     NaN        NaN
# 29                  40    111.0     NaN        NaN
# 30                  41    772.0    20.0   2.525253
# 31                  42    238.0     2.0   0.833333
# 32                  43      9.0     NaN        NaN
# 33                  44      7.0     1.0  12.500000
# 34                  45      9.0     NaN        NaN
# 35                  46      7.0     NaN        NaN
# 36                  47      5.0     NaN        NaN
# 37                  48  30142.0  1140.0   3.644268
# 38                  49     13.0     NaN        NaN
# 39                  50     14.0     NaN        NaN
# 40                  51     42.0     NaN        NaN
# 41                  52    114.0     1.0   0.869565
# 42                  53    703.0    14.0   1.952580
# 43                  54   1070.0    18.0   1.654412
# 44                  55     46.0     NaN        NaN
# 45                  56     49.0     NaN        NaN
# 46                  57     38.0     1.0   2.564103
# 47                  58     24.0     NaN        NaN
# 48                  59     25.0     NaN        NaN
# 49                  60   7476.0   183.0   2.389346
# 50                  61     44.0     1.0   2.222222
# 51                  62     20.0     NaN        NaN
# 52                  63     27.0     NaN        NaN
# 53                  64     31.0     1.0   3.125000
# 54                  65     25.0     NaN        NaN
# 55                  66     47.0     1.0   2.083333
# 56                  67     95.0     2.0   2.061856

# %%
import seaborn as sns, numpy as np
sns.set_theme(); np.random.seed(0)
x = df.QtParcelas
ax = sns.distplot(x)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x = df.QtCilindradaVeiculo
ax = sns.distplot(x)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x = df.QtQuilometragemVeiculo
ax = sns.distplot(x)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.groupby(by='QtAnoIdade').ID.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='QtAnoIdade'>

# %%
df.groupby(by='AaFabricacaoVeiculo').ID.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='AaFabricacaoVeiculo'>

# %%
df.groupby(by=['CdMarca']).ID.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='CdMarca'>

# %%
df.groupby(by=['Sub_Produto', 'fl_renovou']).ID.count().unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Sub_Produto'>

# %%
df.groupby(by='FlZeroKm').ID.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='FlZeroKm'>

# %%
df_model = df.dropna().reset_index()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

num_cols = ['VrContrato','VrFinanciamento','VrEntrada','QtParcelas','AaFabricacaoVeiculo','VrMercado','QtCilindradaVeiculo','QtQuilometragemVeiculo','QtAnoIdade']

df_x = df_model[num_cols]
df_y = df_model['fl_renovou']
X_train, X_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.1, random_state=42)
model = DecisionTreeClassifier().fit(X_train,y_train)
f_imp = model.feature_importances_

f_imp_dict = {k: v for k, v in sorted({num_cols[x]:f_imp[x] for x in range(0,len(num_cols))}.items(), key=lambda item: item[1])}

sns.set_theme(style="whitegrid")
ax = sns.barplot(x=list(f_imp_dict.values()), y=list(f_imp_dict.keys()), orient = 'h')

# %%
from sklearn.metrics import confusion_matrix,f1_score
y_pred = model.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
f1_score = f1_score(y_test,y_pred)
print(f'TN = {tn},\nFP = {fp},\nFN = {fn},\nTP = {tp},\nF1 = {f1_score}')
# Out:
# TN = 4519,
# FP = 165,
# FN = 146,
# TP = 9,
# F1 = 0.0547112462006079

# %%
# The following two lines are only necessary to run once.
# Comment out otherwise for speed-up.
from google.cloud.bigquery import Client, QueryJobConfig
client = Client()

query = """SELECT 
fl_renovou,
duracao_segundos,
VrRenda,
Grupo_Etario,
CdUfNaturalidade,
QtAnoIdade
FROM `hacka-1.dataset.view_dados_hacka`
"""

#Capacidade_de_Pagamento_3,
#Capacidade_de_Pagamento_4,
#Capacidade_de_Pagamento_5,
#Capacidade_de_Pagamento_6,
#Capacidade_de_Pagamento_7,
#ID, NmMotivoContratoFinanceiro,
#Sub_Produto,
#QtAnoIdade, 
#NV_D1_EMPATIA_3m,
#NV_D1_EMPATIA_6m
#where fl_renovou=1
# NV_FC_NEGOCIACAO_COM_SUCESSO_6m,
# NV_FC_NEGOCIACAO_COM_SUCESSO_3m,
#NV_D1_EMPATIA_3m,
#NV_D1_EMPATIA_6m,
#CX_Cortesia_3m,
#CX_Cortesia_6m,
#CX_Cancelamento_6m,
#CX_Oferta_6m,
#VrContrato,
#VrFinanciamento,
#VrEntrada,
#VrMercado,
#QtParcelas,
#FlZeroKm,
#QtCilindradaVeiculo,
#AaFabricacaoVeiculo,
#CdMarca,
#CdOcupacaoCBO,
#QtQuilometragemVeiculo,

job = client.query(query)
df = job.to_dataframe()

# %%
sns.heatmap(df.corr(), cmap = 'Wistia', annot = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1/1324046341.py in <module>
#       1 sns.heatmap(df.corr(), cmap = 'Wistia', annot = True)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined
